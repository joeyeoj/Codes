# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import sys

params={
        # 'axes.labelsize':20,
        # 'xtick.labelsize':'medium',
        # 'ytick.labelsize':'medium',
        'xtick.direction':'in',
        'ytick.direction':'in',
        'xtick.minor.visible':True,
        'ytick.minor.visible':True,
        'xtick.top':True,
        'ytick.right':True,
        'xtick.labeltop':False,
        'ytick.labelright':False,
        'xtick.labelbottom':True,
        'ytick.labelleft':True,
        # 'xtick.major.size':10,
        # 'ytick.major.size':10,
        # 'xtick.minor.size':5,
        # 'ytick.minor.size':5,
        # 'xtick.major.width':1.5,
        # 'ytick.major.width':1.5,
        # 'xtick.minor.width':1,
        # 'ytick.minor.width':1,
        # 'errorbar.capsize':3,
        # 'legend.fontsize':'xx-large',
        'font.family':'serif',
        'mathtext.default':'it',
        'figure.subplot.wspace':0,
        'font.size': 14}
plt.rcParams.update(params)

# %% [markdown]
# #### Merger

# %%
bgd=0.07615
bgd_err=0.0134615
count_bgd=32

# %%
R_30=[1.5,5,24]
count_30=[118,33,31]
surf_30=[69.6392,1.00983,0.0382057]
surf_err_30=[6.41081,0.17579,0.00686194]

R_40=[1.5,2.5,5,16]
count_40=[135,41,30,30]
surf_40=[79.672,14.1147,2.03171,0.0883352]
surf_err_40=[6.85708,2.20435,0.370938,0.0161277]

R_50=[1.5,2.5,4,7.5,35]
count_50=[199,34,34,32,30]
surf_50=[117.442,11.7049,3.79618,0.786884,0.0162729]
surf_err_50=[8.32527,2.00737,0.65104,0.139103,0.00297101]

R_60=[1.5,2.5,4.5,10.5,34.5]
count_60=[225,38,38,32,30]
surf_60=[185.901,14.2712,2.75409,0.329667,0.0214382]
surf_err_60=[12.3934,2.3151,0.446773,0.0582775,0.00391406]

R_70=[1.5,2.5,4,8,16,31]
count_70=[233,50,43,30,30,30]
surf_70=[192.511,20.6557,5.22468,0.613536,0.176293,0.0458506]
surf_err_70=[12.6118,2.92116,0.796756,0.112016,0.0321866,0.00837114]

plt.figure(figsize=(8,6))
plt.errorbar(R_30,surf_30,yerr=surf_err_30,fmt='o',color='b',label='30ks')
plt.errorbar(R_40,surf_40,yerr=surf_err_40,fmt='o',color='g',label='40ks')
plt.errorbar(R_50,surf_50,yerr=surf_err_50,fmt='o',color='r',label='50ks')
plt.errorbar(R_60,surf_60,yerr=surf_err_60,fmt='o',color='c',label='60ks')
plt.errorbar(R_70,surf_70,yerr=surf_err_70,fmt='o',color='m',label='70ks')

# for i, count in enumerate(count):
#     plt.annotate(str(count), (R[i], surf[i]))
plt.ylabel('Surface brightness (counts/arcsec$^2$)')
plt.xlabel('Radius (arcsec)')
# plt.xticks(range(0, 9))
plt.yscale('log')
plt.axhline(y=bgd,color='r',label='Background')
plt.axhline(y=bgd+3*bgd_err,color='green',linestyle='--',label='3$\sigma$ Background')
plt.legend()
plt.axvline(x=1,color='k',linestyle='--')
# plt.show()
# plt.savefig('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/30ks.png',dpi=300)
# plt.close()

# %%
R=[1.5,2.5,5,16]
count=[135,41,30,30]
surf=[79.672,14.1147,2.03171,0.0883352]
surf_err=[6.85708,2.20435,0.370938,0.0161277]

plt.figure(figsize=(8,6))
plt.errorbar(R,surf,yerr=surf_err,fmt='o')
for i, count in enumerate(count):
    plt.annotate(str(count), (R[i], surf[i]))
plt.ylabel('Surface brightness (counts/arcsec$^2$)')
plt.xlabel('Radius (arcsec)')
# plt.xticks(range(0, 9))
plt.yscale('log')
plt.axhline(y=bgd,color='r',label='Background')
plt.axhline(y=bgd+3*bgd_err,color='green',linestyle='--',label='3$\sigma$ Background')
plt.legend()
plt.axvline(x=1,color='k',linestyle='--')
# plt.show()
plt.savefig('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/40ks.png',dpi=300)
# plt.close()

# %%
R=[1.5,2.5,4,7.5,35]
count=[199,34,34,32,30]
surf=[117.442,11.7049,3.79618,0.786884,0.0162729]
surf_err=[8.32527,2.00737,0.65104,0.139103,0.00297101]

plt.figure(figsize=(8,6))
plt.errorbar(R,surf,yerr=surf_err,fmt='o')
for i, count in enumerate(count):
    plt.annotate(str(count), (R[i], surf[i]))
plt.ylabel('Surface brightness (counts/arcsec$^2$)')
plt.xlabel('Radius (arcsec)')
# plt.xticks(range(0, 9))
plt.yscale('log')
plt.axhline(y=bgd,color='r',label='Background')
plt.axhline(y=bgd+3*bgd_err,color='green',linestyle='--',label='3$\sigma$ Background')
plt.legend()
plt.axvline(x=1,color='k',linestyle='--')
# plt.show()
plt.savefig('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/50ks.png',dpi=300)
# plt.close()

# %%
R=[1.5,2.5,4.5,10.5,34.5]
count=[225,38,38,32,30]
surf=[185.901,14.2712,2.75409,0.329667,0.0214382]
surf_err=[12.3934,2.3151,0.446773,0.0582775,0.00391406]

plt.figure(figsize=(8,6))
plt.errorbar(R,surf,yerr=surf_err,fmt='o')
for i, count in enumerate(count):
    plt.annotate(str(count), (R[i], surf[i]))
plt.ylabel('Surface brightness (counts/arcsec$^2$)')
plt.xlabel('Radius (arcsec)')
plt.xlim(0, 15)
plt.xticks(range(0, 16))
plt.yscale('log')
plt.axhline(y=bgd,color='r',label='Background')
plt.axhline(y=bgd+3*bgd_err,color='green',linestyle='--',label='3$\sigma$ Background')
plt.legend()
plt.axvline(x=1,color='k',linestyle='--')
# plt.show()
plt.savefig('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/60ks.png',dpi=300)
# plt.close()

# %%
R=[1.5,2.5,4,8,16,31]
count=[233,50,43,30,30,30]
surf=[192.511,20.6557,5.22468,0.613536,0.176293,0.0458506]
surf_err=[12.6118,2.92116,0.796756,0.112016,0.0321866,0.00837114]

plt.figure(figsize=(8,6))
plt.errorbar(R,surf,yerr=surf_err,fmt='o')
for i, count in enumerate(count):
    plt.annotate(str(count), (R[i], surf[i]))
plt.ylabel('Surface brightness (counts/arcsec$^2$)')
plt.xlabel('Radius (arcsec)')
# plt.xticks(range(0, 9))
plt.yscale('log')
plt.axhline(y=bgd,color='r',label='Background')
plt.axhline(y=bgd+3*bgd_err,color='green',linestyle='--',label='3$\sigma$ Background')
plt.legend()
plt.axvline(x=1,color='k',linestyle='--')
# plt.show()
plt.savefig('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/70ks.png',dpi=300)
# plt.close()

# %%
bgd=0.00437508
bgd_err=0.000761604
count_bgd=33

# %%
R=[0.5,1.5,2.5,3.5,4.5,5.5,6.5,8,10,12.5]
count=[12947,1534,240,98,65,52,35,41,36,39]
surf=[4457.16,171.275,14.3692,4.2616,2.35548,1.46136,0.881646,0.412109,0.283819,0.164235]
surf_err=[39.1718,4.37302,0.927527,0.430486,0.292161,0.202654,0.149025,0.0643606,0.0473031,0.0262986]

# %%
plt.figure(figsize=(8,6))
plt.errorbar(R,surf,yerr=surf_err,fmt='o')
for i, count in enumerate(count):
    plt.annotate(str(count), (R[i], surf[i]))
plt.ylabel('Surface brightness (counts/arcsec$^2$)')
plt.xlabel('Radius (arcsec)')
plt.xlim(0, 15)
plt.xticks(range(0, 16))
plt.yscale('log')
plt.axhline(y=bgd,color='r',label='Background')
plt.axhline(y=bgd+3*bgd_err,color='green',linestyle='--',label='3$\sigma$ Background')
plt.legend()
# plt.show()
plt.savefig('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/60ks_soft.png',dpi=300)
# plt.close()
