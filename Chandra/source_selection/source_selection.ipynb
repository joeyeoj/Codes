# %%
# -*- coding: utf-8 -*-
"""
@Author: Jiayi Chen
Created on Feb. 21, 2024
Last modified on Feb. 23, 2024

Select the red quasars.
"""
import pandas as pd
import numpy as np
from astropy.io import fits
import os
import re
from astropy.coordinates import Angle
from astropy import units as u
# %matplotlib widget

# %% [markdown]
# #### 文件名后缀修改

# %%
# 列出当前目录下所有的文件
directory = '/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial'
files = os.listdir(directory)
for filename in files:
    portion = os.path.splitext(filename)
    # 如果后缀是.fits
    if portion[1] == ".fits":  
        # 重新组合文件名和后缀名
        newname = portion[0]  
        # 使用文件的完整路径重命名文件
        os.rename(os.path.join(directory, filename), os.path.join(directory, newname))

# %%
# 列出当前目录下所有的文件
directory = '/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/1st/WISE'
files = os.listdir(directory)
for filename in files:
    portion = os.path.splitext(filename)
    # 如果后缀是.dat
    if portion[1] == ".dat":  
        # 重新组合文件名和后缀名
        newname = portion[0]+'.txt'
        # 使用文件的完整路径重命名文件
        os.rename(os.path.join(directory, filename), os.path.join(directory, newname))

# %% [markdown]
# #### 修改文件为csv文件

# %%
# # 打开文件并读取所有行到一个列表中
# with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_757_51_table1.txt', 'r') as file:
#     lines = file.readlines()
# parts=lines[0].split('=======================================================================END')
# # 使用正则表达式删除第一个数字前的所有空格
# data = re.sub(r'^\s*(?=\d)', '', parts[1])
# result = data.split('\t')
# fields=result[0].split()
# data_757=[]
# for i in range(len(fields)-3):
#     fields_copy=fields.copy()
#     if fields[i].isdigit()==False and fields[i+1].isdigit()==False and fields[i+2].isdigit() and fields[i+3].isdigit():
#         fields_copy.insert(i+2,'0')
#         fields_copy.insert(i+2,'0')
#         data_757.append(fields_copy[i-16:i+4])
#         continue
#     if fields[i].isdigit()==False and fields[i+1].isdigit()==False and fields[i+2].isdigit()==False and fields[i+3].isdigit():
#         fields_copy.insert(i+2,'0')
#         data_757.append(fields_copy[i-16:i+4])
#         continue
# data_757=data_757[1:]
# for i in range(len(data_757)):
#     data_757[i][0]=data_757[i][0]+' '+data_757[i][1]+' '+data_757[i][2]
#     data_757[i].pop(1)
#     data_757[i].pop(1)
#     data_757[i][1]=data_757[i][1]+' '+data_757[i][2]+' '+data_757[i][3]
#     data_757[i].pop(2)
#     data_757[i].pop(2)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/1st/FIRST-2MASS/J_ApJ_757_51_table1.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
for i in range(len(data)):
    data[i]= [x for x in data[i] if x != 'Sp']
for i in range(len(data)):
    data[i][0]=data[i][0]+' '+data[i][1]+' '+data[i][2]
    data[i].pop(1)
    data[i].pop(1)
    data[i][1]=data[i][1]+' '+data[i][2]+' '+data[i][3]
    data[i].pop(2)
    data[i].pop(2)
for i in range(len(data)):
    if data[i][-1].replace('.', '', 1).isdigit()==False:
        try:
            float(data[i][-2].replace('.', '', 1))
            data[i].append('0')
            data[i].append('0')
            data[i].append('0')
        except ValueError:
            try:
                float(data[i][-3].replace('.', '', 1))
                data[i].append('0')
                data[i].append('0')
            except ValueError:
                try:
                    float(data[i][-4].replace('.', '', 1))
                    data[i].append('0')
                except ValueError:
                    continue
data
# Out:
# [['00 23 47.96',
#   '-01 45 42.7',
#   '21.44',
#   '19.71',
#   '17.25',
#   '16.05',
#   '15.07',
#   '1.09',
#   '0.79',
#   '2.18',
#   '4.64',
#   '0.342',
#   'Galaxy',
#   'O10',
#   '0',
#   '0'],
#  ['00 25 34.91',
#   '-00 52 51.6',
#   '20.90',
#   '19.68',
#   '17.12',
#   '16.56',
#   '15.31',
#   '3.11',
#   '3.47',
#   '1.82',
#   '4.37',
#   '-9.99',
#   '?',
#   'O22',
#   'IR4',
#   '0'],
#  ['00 30 09.10',
#   '-00 27 44.4',
#   '19.68',
#   '18.36',
#   '16.50',
#   '15.34',
#   '14.20',
#   '2.95',
#   '2.52',
#   '2.31',
#   '4.16',
#   '0.242',
#   'Starb?ULIRG',
#   '1996MNRAS.279..459C',
#   '0',
#   '0'],
#  ['00 31 32.62',
#   '+01 30 01.1',
#   '21.84',
#   '19.79',
#   '17.52',
#   '16.79',
#   '15.75',
#   '1.03',
#   '0.55',
#   '1.77',
#   '4.04',
#   '0.38',
#   'Galaxy',
#   'O22',
#   '0',
#   '0'],
#  ['00 36 59.85',
#   '-01 13 32.3',
#   '22.50',
#   '19.53',
#   '16.57',
#   '15.10',
#   '13.63',
#   '1.92',
#   '0.82',
#   '2.94',
#   '5.90',
# ...

# %%
data_757=pd.DataFrame(data,columns=['R.A.(J2000)','Dec(J2000)','B(mag)','R(mag)','J(mag)','H(mag)','Ks(mag)','Fpk(mJy)','Fint(mJy)','J-Ks(mag)','R-Ks(mag)','z','Class','Optical','Near-IR','References'])
data_757.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_757_51_table1.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_426_833_table1.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
data
# Out:
# [['331.2879944', '1.2256938', '1.74', '0.150'],
#  ['353.8881836', '1.2255382', '2.80', '0.143'],
#  ['327.1674805', '1.2590889', '5.52', '0.148'],
#  ['353.0435486', '1.1830354', '18.99', '0.147'],
#  ['37.0628471', '1.1827827', '2.82', '0.138'],
#  ['18.8434620', '1.1813327', '1.10', '0.145'],
#  ['356.9854126', '1.1412108', '14.33', '0.136'],
#  ['325.7733459', '1.1409802', '1.31', '0.140'],
#  ['4.0526733', '1.0520694', '12.77', '0.086'],
#  ['22.6635208', '1.0510056', '13.91', '0.153'],
#  ['47.3892479', '1.0074444', '2.24', '0.151'],
#  ['354.6213684', '1.0069444', '3.64', '0.125'],
#  ['350.3392029', '1.0066222', '24.09', '0.119'],
#  ['325.1291199', '1.0063556', '1.47', '0.136'],
#  ['14.0854664', '0.9571222', '2.31', '0.119'],
#  ['27.8526154', '1.2563722', '1.80', '0.139'],
#  ['37.7157326', '1.1804438', '6.83', '0.149'],
#  ['9.7385740', '1.1796549', '3.72', '0.139'],
#  ['43.9607582', '1.1795660', '1.19', '0.140'],
#  ['328.0464783', '1.1393497', '3.07', '0.134'],
# ...

# %%
data_426=pd.DataFrame(data,columns=['RA J2000','Dec. J2000','Sint1400(mJy)','rms flux(mJy beam-1)'])
data_426.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_426_833_table1.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_778_127_table1.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
for i in range(len(lines)):
    lines[i] = re.sub(r'(>\s+)', '>', lines[i])
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
for i in range(len(data)):
    data[i]= [x for x in data[i] if x != 'X-ray']
    data[i]= [x for x in data[i] if x != 'Source']
for i in range(len(data)):
    data[i][0]=data[i][0]+' '+data[i][1]+' '+data[i][2]
    data[i].pop(1)
    data[i].pop(1)
    data[i][1]=data[i][1]+' '+data[i][2]+' '+data[i][3]
    data[i].pop(2)
    data[i].pop(2)
for i in range(len(data)):
    if data[i][-2].replace('.', '', 1).isdigit():
        if len(data[i])==13:
            data[i].insert(-1,'0')
            data[i].insert(-1,'0')
        else:
            if len(data[i])==12:
                data[i].insert(-1,'0')
                data[i].insert(-1,'0')
                data[i].insert(-1,'0')
    else:
        if data[i][-3].replace('.', '', 1).isdigit():
            if len(data[i])==14:
                data[i].insert(-1,'0')
            else:
                if len(data[i])==13:
                    data[i].insert(-1,'0')
                    data[i].insert(-1,'0')
        else:
            if len(data[i])==14:
                data[i].insert(-1,'0')
data
# Out:
# [['00 12 42.70',
#   '-00 45 14.8',
#   '22.22',
#   '20.55',
#   '19.41',
#   '18.89',
#   '17.77',
#   '16.93',
#   '1.96',
#   '5.29',
#   '1.19',
#   '0911',
#   'QSO',
#   '0',
#   '0.645'],
#  ['00 16 00.62',
#   '-00 38 59.9',
#   '21.72',
#   '21.17',
#   '19.27',
#   '18.83',
#   '17.63',
#   '16.28',
#   '2.55',
#   '5.43',
#   '1.32',
#   '0808',
#   'SDSS3',
#   'QSO',
#   '2.186'],
#  ['00 20 54.02',
#   '+00 20 26.6',
#   '22.29',
#   '20.92',
#   '19.15',
#   '18.69',
#   '17.78',
#   '16.83',
#   '1.86',
#   '5.46',
#   '2.45',
#   '0911',
#   '0',
#   '0',
#   '-9.999'],
#  ['00 27 42.22',
#   '+00 05 40.6',
#   '24.00',
#   '24.36',
#   '18.62',
#   '18.11',
#   '17.10',
#   '16.21',
#   '1.90',
#   '7.80',
#   '2.98',
#   'SDSS3',
#   'Galaxy',
#   '0',
#   '0.415'],
#  ['00 30 04.96',
#   '+00 25 01.3',
#   '21.61',
#   '20.92',
#   '19.12',
#   '18.38',
#   '17.23',
#   '16.11',
#   '2.27',
#   '5.50',
#   '7.5',
#   '0808',
#   'QSO',
#   '0',
#   '2.299'],
# ...

# %%
data_778_1=pd.DataFrame(data,columns=['R.A.(J2000)','Dec(J2000)','r(mag)','i(mag)','Y(mag)','J(mag)','H(mag)','K(mag)','J-K(mag)','r-K(mag)','S20cm','Near-IR','Optical','Class','Redshift'])
data_778_1.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_778_127_table1.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJS_217_5_table1.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split('|')
for i in range(len(data)):
    data[i][1]=data[i][1].split()
    data[i][1][0]=data[i][1][0]+' '+data[i][1][1]+' '+data[i][1][2]
    data[i][1].pop(1)
    data[i][1].pop(1)
    data[i][1][1]=data[i][1][1]+' '+data[i][1][2]+' '+data[i][1][3]
    data[i][1].pop(2)
    data[i][1].pop(2)
    data[i]=[data[i][0],*data[i][1],*data[i][2:]]
data
# Out:
# [['HAQ0000+0557',
#   '00 00 33.979',
#   '+05 57 53.77',
#   '19.75',
#   'NOT, BOSS',
#   '3x780'],
#  ['HAQ0001+0233',
#   '00 01 21.685',
#   '+02 33 04.87',
#   '17.86',
#   'NOT      ',
#   '2x600'],
#  ['HAQ0008+0835',
#   '00 08 15.020',
#   '+08 35 25.68',
#   '18.24',
#   'NOT      ',
#   '2x450'],
#  ['HAQ0008+0846',
#   '00 08 25.327',
#   '+08 46 26.20',
#   '18.81',
#   'NOT      ',
#   '2x600'],
#  ['HAQ0011+0122', '00 11 04.665', '+01 22 56.02', '18.28', 'NOT      ', '900'],
#  ['HAQ0012+0651',
#   '00 12 55.339',
#   '+06 51 22.76',
#   '18.70',
#   'NOT      ',
#   '2x600'],
#  ['HAQ0012+0657',
#   '00 12 43.499',
#   '+06 57 36.74',
#   '18.98',
#   'NOT      ',
#   '2x600'],
#  ['HAQ0012+0944',
#   '00 12 01.587',
#   '+09 44 02.21',
#   '18.13',
#   'NOT      ',
#   '2x500'],
#  ['HAQ0014+0444',
#   '00 14 05.324',
#   '+04 44 09.35',
#   '17.75',
#   'NOT      ',
#   '2x600'],
#  ['HAQ0014+0939',
#   '00 14 13.425',
#   '+09 39 06.47',
#   '18.77',
# ...

# %%
data_217=pd.DataFrame(data,columns=['Target','R.A. (J 2000)','Decl. (J 2000)','rSDSS(mag)','Telescope','Exp. Time(s)'])
data_217.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJS_217_5_table1.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_812_66_table1.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split('|')
for i in range(len(data)):
    del data[i][5]
data
# Out:
# [['0825+4716', '0.803', '0.52', '14.11', '6.42', '2.98'],
#  ['0911+0143', '0.603', '0.63', '14.87', '6.28', '1.59'],
#  ['0915+2418', '0.842', '0.36', '13.79', '6.47', '2.74'],
#  ['1113+1244', '0.681', '1.41', '13.67', '6.06', '2.47'],
#  ['1227+5053', '0.768', '0.38', '14.61', '4.16', '1.71'],
#  ['1248+0531', '0.740', '0.26', '14.63', '6.06', '3.45'],
#  ['1309+6042', '0.641', '0.95', '14.80', '6.77', '3.09'],
#  ['1313+1453', '0.584', '1.12', '14.48', '5.65', '2.30'],
#  ['1434+0935', '0.770', '1.14', '14.90', '6.19', '2.10'],
#  ['1532+2415', '0.562', '0.70', '14.96', '5.13', '1.87'],
#  ['1540+4923', '0.696', '0.97', '15.18', '5.31', '2.28'],
#  ['1600+3522', '0.707', '0.22', '14.17', '4.42', '2.24'],
#  ['1656+3821', '0.732', '0.88', '15.09', '6.91', '2.26'],
#  ['1720+6156', '0.727', '1.50', '15.20', '6.44', '1.95'],
#  ['2325-1052', '0.564', '0.50', '15.24', '4.46', '2.14'],
#  ['2339-0912', '0.660', '1.25', '14.09', '5.16', '1.63']]

# %%
data_812=pd.DataFrame(data,columns=['Objects','Redshift(z)','E(B-V)','K(mag)','r-K(mag)','J-K(mag)'])
data_812.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_812_66_table1.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_464_3431_table2.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
for i in range(len(data)):
    j=0
    while j < len(data[i])-1:
        # 如果当前字符串以 | 结尾
        if data[i][j].endswith('|'):
            # 将当前字符串与后一个字符串连接起来
            data[i][j] += data[i][j+1]
            # 删除后一个字符串
            del data[i][j+1]
        else:
            if data[i][j].endswith('a'):
                data[i][j]=data[i][j].replace('a','')
            # 如果当前字符串不以 | 结尾，移动到下一个字符串
            j += 1
data
# Out:
# [['J000610.67+121501.2',
#   '2.31',
#   '22.1',
#   '8.0',
#   '107|6',
#   '4540|200',
#   '0.37',
#   '1.88',
#   '0',
#   '-0.20',
#   '0.66|0.01',
#   '0.0ND'],
#  ['J000746.19+122223.9',
#   '2.43',
#   '21.3',
#   '4.9',
#   '220|6',
#   '2433|71',
#   '0.28',
#   '0.39',
#   '0',
#   '-0.17',
#   '0.19|0.01',
#   '0.0ND'],
#  ['J002400.25+245031.9',
#   '2.81',
#   '21.6',
#   '6.0',
#   '144|10',
#   '3523|195',
#   '0.37',
#   '2.46',
#   '0',
#   '-1.14',
#   '0.20|0.02',
#   '---'],
#  ['J004713.21+264024.7',
#   '2.56',
#   '20.4',
#   '4.7',
#   '101|2',
#   '3685|74',
#   '0.33',
#   '1.92',
#   '1',
#   '-1.08',
#   '0.15|0.01',
#   '---'],
#  ['J005044.95-021217.6',
#   '2.25',
#   '21.5',
#   '4.7',
#   '147|9',
#   '4343|487',
#   '0.19',
#   '0.61',
#   '0',
#   '-1.73',
#   '0.14|0.02',
#   '0.0ND'],
#  ['J005233.24-055653.5',
#   '2.35',
#   '22.4',
#   '6.4',
#   '188|7',
#   '2451|94',
#   '0.27',
#   '2.03',
#   '0',
#   '1.33',
#   '---',
#   '0.0ND'],
# ...

# %%
data_464_2=pd.DataFrame(data,columns=['Quasar name','ze','i(mag)','i-W3(mag)','REW(A)','FWHM(km s-1)','kt80','NV/CIV','BAL','αλ','E(B-V)','FIRST(mJy)'])
data_464_2.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_464_3431_table2.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_464_3431_tableb1.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
for i in range(len(data)):
    j=0
    while j < len(data[i])-1:
        # 如果当前字符串以 | 结尾
        if data[i][j].endswith('|'):
            # 将当前字符串与后一个字符串连接起来
            data[i][j] += data[i][j+1]
            # 删除后一个字符串
            del data[i][j+1]
        else:
            if data[i][j].endswith('b'):
                data[i][j]=data[i][j].replace('b','')
            # 如果当前字符串不以 | 结尾，移动到下一个字符串
            j += 1
data
# Out:
# [['J000315.85+061331.5',
#   '2.25',
#   '20.6',
#   '4.0',
#   '59|2',
#   '3978|109',
#   '0.35',
#   '1.98',
#   '1',
#   '-0.02',
#   '0.19|0.01',
#   '0.0ND'],
#  ['J001120.22+260109.2',
#   '2.29',
#   '20.2',
#   '4.9',
#   '98|2',
#   '3804|56',
#   '0.34',
#   '2.26',
#   '1',
#   '-0.72',
#   '0.21|0.01',
#   '---'],
#  ['J001809.42+042527.7',
#   '2.55',
#   '20.4',
#   '3.3',
#   '48|3',
#   '4095|185',
#   '0.35',
#   '2.47',
#   '1',
#   '-1.11',
#   '0.06|0.01',
#   '0.0ND'],
#  ['J001911.87+263515.3',
#   '2.24',
#   '20.9',
#   '---',
#   '123|7',
#   '1654|92',
#   '0.33',
#   '0.86',
#   '1',
#   '-2.02',
#   '---',
#   '---'],
#  ['J002044.88+241024.9',
#   '2.58',
#   '20.9',
#   '4.4',
#   '52|3',
#   '4289|195',
#   '0.37',
#   '2.22',
#   '1',
#   '-0.45',
#   '0.09|0.02',
#   '-1.0'],
#  ['J003747.98+170504.0',
#   '3.66',
#   '20.9',
#   '4.5',
#   '122|4',
#   '5609|164',
#   '0.33',
#   '2.38',
#   '0',
#   '---',
#   '---',
#   '---'],
# ...

# %%
data_464_b1=pd.DataFrame(data,columns=['Quasar name','ze','i(mag)','i-W3(mag)','REW(A)','FWHM(km s-1)','kt80','NV/CIV','BAL','αλ','E(B-V)','FIRST(mJy)'])
data_464_b1.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_464_3431_tableb1.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_477_830_table4.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
for i in range(len(data)):
    data[i][0]=data[i][0]+' '+data[i][1]
    data[i].pop(1)
    j=0
    while j < len(data[i])-1:
        if data[i][j]=='<':
            data[i][j]+=data[i][j+1]
            del data[i][j+1]
        else:
            j+=1
for i in range(len(data)):
    data[i][3]=data[i][3]+'|'+data[i][4]
    data[i].pop(4)
data
# Out:
# [['SDSS J000610.67+121501.2', 'main', '2.310', '82|12', '1.45e+41'],
#  ['SDSS J000746.19+122223.9', 'main', '2.429', '39|7', '7.73e+40'],
#  ['SDSS J001120.22+260109.2', 'like', '2.290', '64|8', '1.11e+41'],
#  ['SDSS J002400.25+245031.9', 'main', '2.809', '40|8', '1.10e+41'],
#  ['SDSS J003747.98+170504.0', 'like', '3.664', '47|8', '2.27e+41'],
#  ['SDSS J004713.21+264024.7', 'main', '2.564', '49|8', '1.09e+41'],
#  ['SDSS J005044.95-021217.6', 'main', '2.254', '<29|0', '<4.88e+40'],
#  ['SDSS J005233.24-055653.5', 'main', '2.354', '134|8', '2.47e+41'],
#  ['SDSS J014111.13-031852.5', 'main', '2.559', '45|8', '9.93e+40'],
#  ['SDSS J015222.58+323152.7', 'main', '2.786', '<27|0', '<7.20e+40'],
#  ['SDSS J020932.15+312202.7', 'main', '2.376', '429|8', '8.06e+41'],
#  ['SDSS J022052.11+013711.1', 'main', '3.138', '199|7', '6.91e+41'],
#  ['SDSS J080425.75+470159.0', 'main', '2.772', '<47|0', '<1.25e+41'],
#  ['SDSS J080547.66+454159.0', 'main', '2.326', '62|8', '1.11e+41'],
# ...

# %%
data_477=pd.DataFrame(data,columns=['Source name','ERQ type','z','Fv','Lradio'])
data_477.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_477_830_table4.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/1st/FIRST-2MASS/J_ApJ_698_1095_table1.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
for i in range(len(data)):
    data[i][1]=data[i][1]+' '+data[i][2]+' '+data[i][3]
    data[i].pop(2)
    data[i].pop(2)
    data[i][2]=data[i][2]+data[i][3]+' '+data[i][4]+' '+data[i][5]
    data[i].pop(3)
    data[i].pop(3)
    data[i].pop(3)
for i in range(len(data)):
    # 找到最后一个数字的位置
    index = next(j for j in reversed(range(len(data[i]))) if re.match(r'^-?\d+(\.\d+)?$', data[i][j]))
    # 删除这个位置后的所有元素
    data[i] = data[i][:index+1]
for i in range(len(data)):
    if len(data[i])==16:
        data[i][-3]=data[i][-3]+' '+data[i][-2]
        data[i].pop(-2)
    else:
        if len(data[i])==12:
            data[i].append('-')
            data[i].append('-')
            data[i].append('none')
data
# Out:
# [['1',
#   '0 36 59.85',
#   '-1 13 32.30',
#   '1.92',
#   '22.09',
#   '21.40',
#   '20.23',
#   '19.72',
#   '16.57',
#   '13.63',
#   '6.60',
#   '2.94',
#   'ESI',
#   'QSO',
#   '0.2940'],
#  ['2',
#   '1 34 35.68',
#   '-9 31 3.00',
#   '900.38',
#   '25.87',
#   '23.65',
#   '21.19',
#   '19.61',
#   '16.19',
#   '13.58',
#   '7.61',
#   '2.61',
#   'NOT',
#   'QSO',
#   '2.2160'],
#  ['3',
#   '1 56 47.61',
#   '-0 58 7.46',
#   '6.51',
#   '21.38',
#   '20.92',
#   '20.11',
#   '19.54',
#   '17.43',
#   '14.87',
#   '5.24',
#   '2.56',
#   'ESI',
#   'NLAGN',
#   '0.5070'],
#  ['4',
#   '7 30 51.03',
#   '+25 38 59.03',
#   '1.23',
#   '22.01',
#   '20.59',
#   '19.49',
#   '19.07',
#   '16.85',
#   '14.15',
#   '5.34',
#   '2.70',
#   'ESI',
#   'NLAGN',
#   '0.2890'],
#  ['5',
#   '7 36 24.18',
#   '+42 22 17.15',
#   '3.93',
#   '22.50',
#   '22.34',
#   '21.63',
#   '20.90',
#   '17.08',
#   '15.46',
#   '6.17',
#   '1.62',
#   '-',
#   '-',
#   'none'],
#  ['6',
# ...

# %%
data_698=pd.DataFrame(data,columns=['No.','R.A.','Decl','Fpk','u','g','r','i','J','K','r-K','J-K','Spect.','Type','z'])
data_698.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_698_1095_table1.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/1st/WISE/J_ApJ_861_37_table5.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
for i in range(len(data)):
    data[i]= [x for x in data[i] if x != 'a']
for i in range(len(data)):
    if len(data[i])==8:
        data[i][0]=data[i][0]+' '+data[i][1]
        data[i].pop(1)
    if len(data[i])==5:
        data[i].insert(4, '0')
        data[i].insert(4, '0')
data
# Out:
# [['J2305-0039', 'Ws82', 'J230525.88-003925.7', '3.106', '0', '0', 'Tsai15'],
#  ['Ws82 J0258-0010',
#   'Ws82',
#   'J025824.21-001038.3',
#   '0.969',
#   '0.55',
#   '3.66',
#   'LRIS'],
#  ['W2M J0043+0052',
#   'W2M',
#   'J004341.25+005253.3',
#   '0.828',
#   '0.66',
#   '3.96',
#   'SDSS/TSpec'],
#  ['W2M J2255+0049',
#   'Ws82',
#   'J225523.32+004943.1',
#   '0.812',
#   '0.86',
#   '5.14',
#   'Kast/SpeX'],
#  ['Ws82 J2346-0036',
#   'Ws82',
#   'J234658.41-003806.5',
#   '0.810',
#   '0.73',
#   '4.37',
#   'SALT/SpeX'],
#  ['Ws82 J0035+0114',
#   'Ws82',
#   'J003514.49+011430.4',
#   '0.805',
#   '0.32',
#   '1.91',
#   'Kast/TSpecP200'],
#  ['Ws82 J0050-0039',
#   'Ws82',
#   'J005009.81-003900.6',
#   '0.728',
#   '0.27',
#   '1.53',
#   'SDSS/TSpecP200'],
#  ['W2M J0129-0059',
#   'W2M',
#   'J012925.81-005900.3',
#   '0.710',
#   '0.49',
#   '2.73',
#   'SDSS/TSpec'],
#  ['W2M J0322+0003',
#   'W2M',
#   'J032247.32+000326.1',
#   '0.603',
#   '0.28',
#   '1.45',
# ...

# %%
data_861=pd.DataFrame(data,columns=['AName','Set','Name','z_sp','E(B-V)(mag)','A_V(mag)','Spectrum'])
data_861.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_861_37_table5.csv',index=False)

# %%
# 打开文件并读取所有行到一个列表中
with open('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/1st/FIRST-2MASS/J_ApJ_667_673_table1.txt', 'r') as file:
    lines = file.readlines()
# 删除每个字符串末尾的换行符
lines = [line.rstrip('\n') for line in lines]
lines
data=[]
for line in lines:
    data.append(line)
for i in range(len(data)):
    data[i]=data[i].split()
# for i in range(len(data)):
#     data[i]= [x for x in data[i] if x != 'Sp']
for i in range(len(data)):
    data[i][0]=data[i][0]+' '+data[i][1]+' '+data[i][2]
    data[i].pop(1)
    data[i].pop(1)
    if data[i][1]=='-':
        data[i][1]=data[i][1]+data[i][2]+' '+data[i][3]+' '+data[i][4]
        data[i].pop(2)
        data[i].pop(2)
        data[i].pop(2)
    else:
        data[i][1]=data[i][1]+' '+data[i][2]+' '+data[i][3]
        data[i].pop(2)
        data[i].pop(2)
for i in range(len(data)):
    if len(data[i])!=15:
        if len(data[i])==16:
            data[i][-2]=data[i][-2]+' '+data[i][-1]
            data[i].pop(-1)
        else:
            data[i].extend(['-']*(15-len(data[i])))
data
# Out:
# [['0 23 47.96',
#   '-1 45 42.7',
#   '1.09',
#   '0.79',
#   '21.44',
#   '19.71',
#   '17.199',
#   '16.040',
#   '15.106',
#   '2.09',
#   '4.60',
#   'Galaxy',
#   '0.3420',
#   'O10',
#   '-'],
#  ['0 36 59.85',
#   '-1 13 32.3',
#   '1.92',
#   '0.82',
#   '99.90',
#   '19.53',
#   '16.532',
#   '15.106',
#   '13.645',
#   '2.89',
#   '5.89',
#   'QSO',
#   '0.2940',
#   'O5',
#   '-'],
#  ['0 44 2.81',
#   '-10 54 18.9',
#   '38.60',
#   '42.57',
#   '22.34',
#   '19.10',
#   '17.765',
#   '16.099',
#   '15.058',
#   '2.71',
#   '4.04',
#   'Galaxy',
#   '0.4310',
#   'O7',
#   'Gl04'],
#  ['1 17 12.76',
#   '-1 27 55.4',
#   '8.34',
#   '8.66',
#   '>22.50',
#   '>20.80',
#   '17.278',
#   '16.361',
#   '15.333',
#   '1.94',
#   '5.47',
#   'Galaxy',
#   '0.8640',
#   'O10',
#   'Gl04'],
#  ['1 34 35.68',
#   '-9 31 3.0',
#   '900.38',
#   '920.52',
#   '>22.50',
#   '>20.80',
#   '16.171',
#   '14.748',
#   '13.546',
#   '2.62',
#   '>7.25',
#   'QSO',
#   '2.2200',
# ...

# %%
data_861=pd.DataFrame(data,columns=['R.A. (J2000.0)','Decl. (J2000.0)','Fpk(mJy)','Fint(mJy)','B(mag)','R(mag)','J(mag)','H(mag)','Ks(mag)','J-K(mag)','R-K(mag)','Type','Redshift(z)','Observations','References'])
data_861.to_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_667_673_table1.csv',index=False)

# %% [markdown]
# #### 合并全部文件中的源

# %%
data_757=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_757_51_table1.csv')
data_778=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_778_127_table1.csv')
data_217=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJS_217_5_table1.csv')
data_464_2=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_464_3431_table2.csv')
data_464_b1=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_464_3431_tableb1.csv')
data_477=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_MNRAS_477_830_table4.csv')
data_698=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_698_1095_table1.csv')
data_861=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_861_37_table5.csv')
data_667=pd.read_csv('/Users/joey/Documents/Work/Proposals/Prop_CJY_2024/Initial/J_ApJ_667_673_table1.csv')

# %%
data_757, data_778, data_217, data_464_2, data_464_b1, data_477, data_698, data_861, data_667
# Out:
# (     R.A.(J2000)   Dec(J2000)  B(mag)  R(mag)  J(mag)  H(mag)  Ks(mag)  \
#  0    00 23 47.96  -01 45 42.7   21.44   19.71   17.25   16.05    15.07
#  1    00 25 34.91  -00 52 51.6   20.90   19.68   17.12   16.56    15.31
#  2    00 30 09.10  -00 27 44.4   19.68   18.36   16.50   15.34    14.20
#  3    00 31 32.62  +01 30 01.1   21.84   19.79   17.52   16.79    15.75
#  4    00 36 59.85  -01 13 32.3   22.50   19.53   16.57   15.10    13.63
#  ..           ...          ...     ...     ...     ...     ...      ...
#  390  23 45 54.91  -10 03 29.1   21.18   18.48   16.82   15.77    14.20
#  391  23 46 00.71  -02 24 48.0   21.67   19.16   16.86   16.07    15.15
#  392  23 50 40.11  -10 43 59.2   21.27   19.24   17.09   15.93    15.03
#  393  23 52 50.23  -02 07 08.8   22.31   19.67   17.36   16.17    15.59
#  394  23 55 28.34  -09 23 13.4   22.50   20.22   17.22   16.00    15.33
#
#       Fpk(mJy)  Fint(mJy)  J-Ks(mag)  R-Ks(mag)      z        Class  \
# ...

# %%
ra=[]
dec=[]
for i in range(len(data_757)):
    hms_string = data_757['R.A.(J2000)'][i]
    dms_string = data_757['Dec(J2000)'][i]
    # 创建一个Angle对象
    angle_ra = Angle(hms_string, unit=u.hour)
    angle_dec = Angle(dms_string, unit=u.degree)
    # 转换为度
    ra_deg = angle_ra.degree
    dec_deg = angle_dec.degree
    ra.append(ra_deg)
    dec.append(dec_deg)
data_757.insert(2,'RA(degree)',ra)
data_757.insert(3,'Dec(degree)',dec)
data_757
# Out:
#      R.A.(J2000)   Dec(J2000)  RA(degree)  Dec(degree)  B(mag)  R(mag)  \
# 0    00 23 47.96  -01 45 42.7    5.949833    -1.761861   21.44   19.71
# 1    00 25 34.91  -00 52 51.6    6.395458    -0.881000   20.90   19.68
# 2    00 30 09.10  -00 27 44.4    7.537917    -0.462333   19.68   18.36
# 3    00 31 32.62  +01 30 01.1    7.885917     1.500306   21.84   19.79
# 4    00 36 59.85  -01 13 32.3    9.249375    -1.225639   22.50   19.53
# ..           ...          ...         ...          ...     ...     ...
# 390  23 45 54.91  -10 03 29.1  356.478792   -10.058083   21.18   18.48
# 391  23 46 00.71  -02 24 48.0  356.502958    -2.413333   21.67   19.16
# 392  23 50 40.11  -10 43 59.2  357.667125   -10.733111   21.27   19.24
# 393  23 52 50.23  -02 07 08.8  358.209292    -2.119111   22.31   19.67
# 394  23 55 28.34  -09 23 13.4  358.868083    -9.387056   22.50   20.22
#
#      J(mag)  H(mag)  Ks(mag)  Fpk(mJy)  Fint(mJy)  J-Ks(mag)  R-Ks(mag)  \
# ...

# %%
source_757=pd.DataFrame({'RA(hms)':data_757['R.A.(J2000)'], 'Dec(dms)':data_757['Dec(J2000)'], 'RA(deg)':data_757['RA(degree)'], 'Dec(deg)':data_757['Dec(degree)'], 'Redshift(z)':data_757['z']})
source_757
# Out:
#          RA(hms)     Dec(dms)     RA(deg)   Dec(deg)  Redshift(z)
# 0    00 23 47.96  -01 45 42.7    5.949833  -1.761861        0.342
# 1    00 25 34.91  -00 52 51.6    6.395458  -0.881000       -9.990
# 2    00 30 09.10  -00 27 44.4    7.537917  -0.462333        0.242
# 3    00 31 32.62  +01 30 01.1    7.885917   1.500306        0.380
# 4    00 36 59.85  -01 13 32.3    9.249375  -1.225639        0.294
# ..           ...          ...         ...        ...          ...
# 390  23 45 54.91  -10 03 29.1  356.478792 -10.058083        0.263
# 391  23 46 00.71  -02 24 48.0  356.502958  -2.413333        0.382
# 392  23 50 40.11  -10 43 59.2  357.667125 -10.733111        0.253
# 393  23 52 50.23  -02 07 08.8  358.209292  -2.119111       -9.990
# 394  23 55 28.34  -09 23 13.4  358.868083  -9.387056        0.512
#
# [395 rows x 5 columns]

# %%
# ra=[]
# dec=[]
# for i in range(len(data_426)):
#     ra_deg = data_426['RA J2000'][i]
#     dec_deg = data_426['Dec. J2000'][i]
#     # 创建一个Angle对象
#     angle_ra = Angle(ra_deg, unit='degree')
#     angle_dec = Angle(dec_deg, unit='degree')
#     # 转换为HMS格式
#     hms_ra_string = angle_ra.to_string(unit='hour', sep=':', precision=2)
#     hms_dec_string = angle_dec.to_string(unit='degree', sep=':', precision=1)
#     ra.append(hms_ra_string)
#     dec.append(hms_dec_string)
# data_426.insert(2,'RA(hms)',ra)
# data_426.insert(3,'Dec(hms)',dec)
# data_426

# %%
ra=[]
dec=[]
for i in range(len(data_778_1)):
    hms_string = data_778_1['R.A.(J2000)'][i]
    dms_string = data_778_1['Dec(J2000)'][i]
    # 创建一个Angle对象
    angle_ra = Angle(hms_string, unit=u.hour)
    angle_dec = Angle(dms_string, unit=u.degree)
    # 转换为度
    ra_deg = angle_ra.degree
    dec_deg = angle_dec.degree
    ra.append(ra_deg)
    dec.append(dec_deg)
data_778_1.insert(2,'RA(degree)',ra)
data_778_1.insert(3,'Dec(degree)',dec)
data_778_1
# Out:
#     R.A.(J2000)   Dec(J2000)  RA(degree)  Dec(degree) r(mag) i(mag) Y(mag)  \
# 0   00 12 42.70  -00 45 14.8    3.177917    -0.754111  22.22  20.55  19.41
# 1   00 16 00.62  -00 38 59.9    4.002583    -0.649972  21.72  21.17  19.27
# 2   00 20 54.02  +00 20 26.6    5.225083     0.340722  22.29  20.92  19.15
# 3   00 27 42.22  +00 05 40.6    6.925917     0.094611  24.00  24.36  18.62
# 4   00 30 04.96  +00 25 01.3    7.520667     0.417028  21.61  20.92  19.12
# ..          ...          ...         ...          ...    ...    ...    ...
# 82  23 34 54.44  +00 16 10.5  353.726833     0.269583  22.20  20.40  19.49
# 83  23 36 33.52  -00 49 57.3  354.139667    -0.832583  21.81  21.00  19.39
# 84  23 37 23.59  -00 58 11.3  354.348292    -0.969806  21.83  21.08  19.45
# 85  23 37 56.73  -00 32 22.6  354.486375    -0.539611  22.10  20.64  19.15
# 86  23 40 15.28  -00 10 33.7  355.063667    -0.176028  21.31  20.53  19.00
#
# ...

# %%
source_778=pd.DataFrame({'RA(hms)':data_778['R.A.(J2000)'], 'Dec(dms)':data_778['Dec(J2000)'], 'RA(deg)':data_778['RA(degree)'], 'Dec(deg)':data_778['Dec(degree)'], 'Redshift(z)':data_778['Redshift']})
source_778
# Out:
#         RA(hms)     Dec(dms)     RA(deg)  Dec(deg) Redshift(z)
# 0   00 12 42.70  -00 45 14.8    3.177917 -0.754111       0.645
# 1   00 16 00.62  -00 38 59.9    4.002583 -0.649972       2.186
# 2   00 20 54.02  +00 20 26.6    5.225083  0.340722      -9.999
# 3   00 27 42.22  +00 05 40.6    6.925917  0.094611       0.415
# 4   00 30 04.96  +00 25 01.3    7.520667  0.417028       2.299
# ..          ...          ...         ...       ...         ...
# 82  23 34 54.44  +00 16 10.5  353.726833  0.269583      -9.999
# 83  23 36 33.52  -00 49 57.3  354.139667 -0.832583      merger
# 84  23 37 23.59  -00 58 11.3  354.348292 -0.969806      -9.999
# 85  23 37 56.73  -00 32 22.6  354.486375 -0.539611       0.719
# 86  23 40 15.28  -00 10 33.7  355.063667 -0.176028      -9.999
#
# [87 rows x 5 columns]

# %%
ra=[]
dec=[]
for i in range(len(data_217)):
    hms_string = data_217['R.A. (J 2000)'][i]
    dms_string = data_217['Decl. (J 2000)'][i]
    # 创建一个Angle对象
    angle_ra = Angle(hms_string, unit=u.hour)
    angle_dec = Angle(dms_string, unit=u.degree)
    # 转换为度
    ra_deg = angle_ra.degree
    dec_deg = angle_dec.degree
    ra.append(ra_deg)
    dec.append(dec_deg)
data_217.insert(3,'RA(degree)',ra)
data_217.insert(4,'Dec(degree)',dec)
data_217
# Out:
#            Target R.A. (J 2000) Decl. (J 2000)  RA(degree)  Dec(degree)  \
# 0    HAQ0000+0557  00 00 33.979   +05 57 53.77    0.141579     5.964936
# 1    HAQ0001+0233  00 01 21.685   +02 33 04.87    0.340354     2.551353
# 2    HAQ0008+0835  00 08 15.020   +08 35 25.68    2.062583     8.590467
# 3    HAQ0008+0846  00 08 25.327   +08 46 26.20    2.105529     8.773944
# 4    HAQ0011+0122  00 11 04.665   +01 22 56.02    2.769437     1.382228
# ..            ...           ...            ...         ...          ...
# 154  HAQ2352+0105  23 52 38.088   +01 05 52.35  358.158700     1.097875
# 155  HAQ2358+0339  23 58 33.476   +03 39 55.79  359.639483     3.665497
# 156  HAQ2358+0359  23 58 16.016   +03 59 44.69  359.566733     3.995747
# 157  HAQ2358+0520  23 58 46.404   +05 20 52.00  359.693350     5.347778
# 158  HAQ2358+1436  23 58 19.661   +14 36 42.03  359.581921    14.611675
#
#      rSDSS(mag)  Telescope Exp. Time(s)
# 0         19.75  NOT, BOSS        3x780
# ...

# %%
# data_757.insert(0,'Flag',0)
# data_426.insert(0,'Flag',0)
# print(len(data_757),len(data_426))
# data_757_426 = pd.DataFrame()
# for i, row1 in data_757.iterrows():
#     for j, row2 in data_426.iterrows():
#         if abs(row1['RA(degree)'] - row2['RA J2000']) < 0.01 and abs(row1['Dec(degree)'] - row2['Dec. J2000']) < 0.01:
#             data_757.at[i,'Flag']=1
#             data_426.at[j,'Flag']=1
#             row1 = row1.drop(row1.index[0])
#             row2 = row2.drop(row2.index[0])
#             merged_row = pd.concat([row1, row2])
#             # 将合并后的行转换为DataFrame并添加到data_757_426中
#             data_757_426 = pd.concat([data_757_426, pd.DataFrame(merged_row).T], ignore_index=True)
# data_757 = data_757.drop(data_757[data_757['Flag'] == 1].index)
# data_426 = data_426.drop(data_426[data_426['Flag'] == 1].index)
# data_757 = data_757.drop(columns=['Flag'])
# data_426 = data_426.drop(columns=['Flag'])
# data_757=data_757.reset_index(drop=True)
# data_426=data_426.reset_index(drop=True)
# print(len(data_757),len(data_426))
# data_757_426

# %%
df=pd.concat([source_757,source_778_1],ignore_index=True)
print(len(df))
# 找到重复的行
duplicates = df[df.duplicated(subset=['RA(hms)', 'Dec(dms)'], keep=False)]
# 去重
df = df.drop_duplicates(subset=['RA(hms)', 'Dec(dms)'])

# 打印df和duplicates
print(df)
print(duplicates)
# Out:
# 482
#          RA(hms)     Dec(dms)     RA(deg)  Dec(deg) Redshift(z)
# 0    00 23 47.96  -01 45 42.7    5.949833 -1.761861       0.342
# 1    00 25 34.91  -00 52 51.6    6.395458 -0.881000       -9.99
# 2    00 30 09.10  -00 27 44.4    7.537917 -0.462333       0.242
# 3    00 31 32.62  +01 30 01.1    7.885917  1.500306        0.38
# 4    00 36 59.85  -01 13 32.3    9.249375 -1.225639       0.294
# ..           ...          ...         ...       ...         ...
# 477  23 34 54.44  +00 16 10.5  353.726833  0.269583      -9.999
# 478  23 36 33.52  -00 49 57.3  354.139667 -0.832583      merger
# 479  23 37 23.59  -00 58 11.3  354.348292 -0.969806      -9.999
# 480  23 37 56.73  -00 32 22.6  354.486375 -0.539611       0.719
# 481  23 40 15.28  -00 10 33.7  355.063667 -0.176028      -9.999
#
# [480 rows x 5 columns]
#          RA(hms)     Dec(dms)    RA(deg)  Dec(deg) Redshift(z)
# 4    00 36 59.85  -01 13 32.3   9.249375 -1.225639       0.294
# ...

# %%
data_812
# Out:
#       Objects  Redshift(z)  E(B-V)  K(mag)  r-K(mag)  J-K(mag)
# 0   0825+4716        0.803    0.52   14.11      6.42      2.98
# 1   0911+0143        0.603    0.63   14.87      6.28      1.59
# 2   0915+2418        0.842    0.36   13.79      6.47      2.74
# 3   1113+1244        0.681    1.41   13.67      6.06      2.47
# 4   1227+5053        0.768    0.38   14.61      4.16      1.71
# 5   1248+0531        0.740    0.26   14.63      6.06      3.45
# 6   1309+6042        0.641    0.95   14.80      6.77      3.09
# 7   1313+1453        0.584    1.12   14.48      5.65      2.30
# 8   1434+0935        0.770    1.14   14.90      6.19      2.10
# 9   1532+2415        0.562    0.70   14.96      5.13      1.87
# 10  1540+4923        0.696    0.97   15.18      5.31      2.28
# 11  1600+3522        0.707    0.22   14.17      4.42      2.24
# 12  1656+3821        0.732    0.88   15.09      6.91      2.26
# 13  1720+6156        0.727    1.50   15.20      6.44      1.95
# ...

# %%
data_464_2
# Out:
#             Quasar name    ze  i(mag)  i-W3(mag)  REW(A) FWHM(km s-1)  kt80  \
# 0   J000610.67+121501.2  2.31    22.1        8.0   107|6     4540|200  0.37
# 1   J000746.19+122223.9  2.43    21.3        4.9   220|6      2433|71  0.28
# 2   J002400.25+245031.9  2.81    21.6        6.0  144|10     3523|195  0.37
# 3   J004713.21+264024.7  2.56    20.4        4.7   101|2      3685|74  0.33
# 4   J005044.95-021217.6  2.25    21.5        4.7   147|9     4343|487  0.19
# ..                  ...   ...     ...        ...     ...          ...   ...
# 92  J223754.52+065026.6  2.61    22.0        5.8   141|5      1391|44  0.36
# 93  J225438.30+232714.5  3.09    22.0        5.5  415|20     4412|146  0.36
# 94  J232326.17-010033.1  2.36    22.4        7.2   256|5      3989|62  0.37
# 95  J232828.47+044346.8  2.56    21.5        5.5   359|5      1584|20  0.35
# 96  J233636.99+065231.0  2.78    22.2        6.0   128|6      1484|83  0.26
#
#     NV/CIV  BAL    αλ     E(B-V) FIRST(mJy)
# ...

# %%
data_464_b1
# Out:
#              Quasar name    ze  i(mag) i-W3(mag) REW(A) FWHM(km s-1)  kt80  \
# 0    J000315.85+061331.5  2.25    20.6       4.0   59|2     3978|109  0.35
# 1    J001120.22+260109.2  2.29    20.2       4.9   98|2      3804|56  0.34
# 2    J001809.42+042527.7  2.55    20.4       3.3   48|3     4095|185  0.35
# 3    J001911.87+263515.3  2.24    20.9       ---  123|7      1654|92  0.33
# 4    J002044.88+241024.9  2.58    20.9       4.4   52|3     4289|195  0.37
# ..                   ...   ...     ...       ...    ...          ...   ...
# 230  J233507.23+074335.5  2.76    20.8       4.7   75|2      2074|52  0.35
# 231  J233720.66-015438.9  3.16    21.2       ---   61|3      2029|80  0.34
# 232  J234933.29+322628.9  2.33    22.1       ---  112|6     2366|113  0.35
# 233  J235010.00+185021.0  2.50    20.7       3.6   46|3     3641|184  0.36
# 234  J235556.69+014747.7  2.25    20.2       3.1   49|2     3295|104  0.37
#
#      NV/CIV  BAL     αλ     E(B-V) FIRST(mJy)
# ...

# %%
df=pd.concat([data_464_2,data_464_b1],ignore_index=True)
print(len(df))
# 找到重复的行
duplicates = df[df.duplicated(subset=['Quasar name'], keep=False)]
# 去重
df = df.drop_duplicates(subset=['Quasar name'])

# 打印df和duplicates
print(df)
print(duplicates)
# Out:
# 332
#              Quasar name    ze  i(mag) i-W3(mag)  REW(A) FWHM(km s-1)  kt80  \
# 0    J000610.67+121501.2  2.31    22.1       8.0   107|6     4540|200  0.37
# 1    J000746.19+122223.9  2.43    21.3       4.9   220|6      2433|71  0.28
# 2    J002400.25+245031.9  2.81    21.6       6.0  144|10     3523|195  0.37
# 3    J004713.21+264024.7  2.56    20.4       4.7   101|2      3685|74  0.33
# 4    J005044.95-021217.6  2.25    21.5       4.7   147|9     4343|487  0.19
# ..                   ...   ...     ...       ...     ...          ...   ...
# 327  J233507.23+074335.5  2.76    20.8       4.7    75|2      2074|52  0.35
# 328  J233720.66-015438.9  3.16    21.2       ---    61|3      2029|80  0.34
# 329  J234933.29+322628.9  2.33    22.1       ---   112|6     2366|113  0.35
# 330  J235010.00+185021.0  2.50    20.7       3.6    46|3     3641|184  0.36
# 331  J235556.69+014747.7  2.25    20.2       3.1    49|2     3295|104  0.37
#
#      NV/CIV  BAL     αλ     E(B-V) FIRST(mJy)
# ...

# %%
data_477
# Out:
#                   Source name ERQ type      z     Fv     Lradio
# 0    SDSS J000610.67+121501.2     main  2.310  82|12   1.45e+41
# 1    SDSS J000746.19+122223.9     main  2.429   39|7   7.73e+40
# 2    SDSS J001120.22+260109.2     like  2.290   64|8   1.11e+41
# 3    SDSS J002400.25+245031.9     main  2.809   40|8   1.10e+41
# 4    SDSS J003747.98+170504.0     like  3.664   47|8   2.27e+41
# ..                        ...      ...    ...    ...        ...
# 96   SDSS J223754.52+065026.6     main  2.609  <28|0  <6.44e+40
# 97   SDSS J225438.30+232714.5     main  3.087  <28|0  <9.47e+40
# 98   SDSS J232326.17-010033.1     main  2.356  <34|0  <6.31e+40
# 99   SDSS J232828.47+044346.8     main  2.564  <48|0  <1.05e+41
# 100  SDSS J233636.99+065231.0     main  2.776   54|7   1.44e+41
#
# [101 rows x 5 columns]

# %%
1*u.W.to(u.erg/u.s)
# Out:
# 10000000.0
